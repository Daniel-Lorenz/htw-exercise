# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
from tensorflow.keras.models import Sequential
from tensorflow.python.keras.layers import GlobalMaxPooling1D
from tensorflow.keras.layers import Embedding, Dense, GRU, Conv1D, LSTM, MaxPooling1D, SimpleRNN, Flatten, Dropout
from humor_detector import HumorDetector

# %%
detector = HumorDetector()
embedding_dim = detector.embedding_dim
embedding_matrix = detector.embedding_matrix
vocabulary_size = detector.vocabulary_size
words_in_sentence = detector.max_number_of_words_in_sentence
# Out:
# 2020-11-05 12:03:48,177 - humor_detector - INFO - This is your HumorDetector. I am ready to work!

# %%
model = Sequential()
# TODO Start thinking/coding here

model.add(Embedding(vocabulary_size, 32))

# TODO End thinking/coding here
model.add(Dense(1, activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, None, 32)          320000
# _________________________________________________________________
# dense (Dense)                (None, None, 1)           33
# =================================================================
# Total params: 320,033
# Trainable params: 320,033
# Non-trainable params: 0
# _________________________________________________________________

# %%
detector.train_model_and_plot_results(model)
# Out:
# 2020-11-05 12:03:55,138 - humor_detector - INFO - I will start model compilation.
# 2020-11-05 12:03:55,150 - humor_detector - INFO - Model has been compiled.
# 2020-11-05 12:03:55,151 - humor_detector - INFO - I will start training.
# Epoch 1/20
# 296/296 [==============================] - 2s 5ms/step - loss: 0.6907 - acc: 0.5411 - __f1__: 1.1765 - val_loss: 0.6881 - val_acc: 0.5609 - val___f1__: 1.2214
# Epoch 2/20
# 296/296 [==============================] - 1s 4ms/step - loss: 0.6866 - acc: 0.5599 - __f1__: 1.2735 - val_loss: 0.6840 - val_acc: 0.5693 - val___f1__: 1.2561
# Epoch 3/20
# 296/296 [==============================] - 1s 4ms/step - loss: 0.6825 - acc: 0.5664 - __f1__: 1.3016 - val_loss: 0.6799 - val_acc: 0.5728 - val___f1__: 1.2742
# Epoch 4/20
# 296/296 [==============================] - 1s 4ms/step - loss: 0.6784 - acc: 0.5702 - __f1__: 1.3205 - val_loss: 0.6761 - val_acc: 0.5750 - val___f1__: 1.2846
# Epoch 5/20
# 296/296 [==============================] - 1s 4ms/step - loss: 0.6745 - acc: 0.5728 - __f1__: 1.3333 - val_loss: 0.6725 - val_acc: 0.5767 - val___f1__: 1.2942
# Epoch 6/20
# 296/296 [==============================] - 1s 4ms/step - loss: 0.6710 - acc: 0.5746 - __f1__: 1.3435 - val_loss: 0.6693 - val_acc: 0.5778 - val___f1__: 1.2981
# Epoch 7/20
# 296/296 [==============================] - 1s 4ms/step - loss: 0.6678 - acc: 0.5760 - __f1__: 1.3490 - val_loss: 0.6666 - val_acc: 0.5790 - val___f1__: 1.3066
# Epoch 8/20
